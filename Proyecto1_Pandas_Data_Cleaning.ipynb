# %%
import pandas as pd
import re

# %%
df = pd.read_csv("input/attacks.csv", engine = "python")

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.head(25)
# Out:
#      Case Number                  Date    Year          Type       Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %% [markdown]
# ## Selecciono las columnas que me interesan y arreglo los espacios de las columnas Sex y Species

# %%
df1 = df[['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
       'Species ']]
df2 = df1.rename(columns = {'Sex ': 'Sex', 'Species ': 'Species'})
df2.head(20)
# Out:
#      Case Number                  Date    Year          Type       Country  \
# 0     2018.06.25           25-Jun-2018  2018.0       Boating           USA
# 1     2018.06.18           18-Jun-2018  2018.0    Unprovoked           USA
# 2     2018.06.09           09-Jun-2018  2018.0       Invalid           USA
# 3     2018.06.08           08-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 4     2018.06.04           04-Jun-2018  2018.0      Provoked        MEXICO
# 5   2018.06.03.b           03-Jun-2018  2018.0    Unprovoked     AUSTRALIA
# 6   2018.06.03.a           03-Jun-2018  2018.0    Unprovoked        BRAZIL
# 7     2018.05.27           27-May-2018  2018.0    Unprovoked           USA
# 8   2018.05.26.b           26-May-2018  2018.0    Unprovoked           USA
# 9   2018.05.26.a           26-May-2018  2018.0    Unprovoked           USA
# 10    2018.05.24           24-May-2018  2018.0      Provoked     AUSTRALIA
# ...

# %% [markdown]
# ## Explorando las columnas para limpiarlas y buscar un supuesto interesante

# %%
df2.Country.groupby(df1["Country"]).count().sort_values(ascending = False)
# Out:
# Country
# USA                      2229
# AUSTRALIA                1338
# SOUTH AFRICA              579
# PAPUA NEW GUINEA          134
# NEW ZEALAND               128
#                          ...
# NETHERLANDS ANTILLES        1
# NEVIS                       1
# NICARAGUA                   1
# NORTH ATLANTIC OCEAN        1
#  PHILIPPINES                1
# Name: Country, Length: 212, dtype: int64

# %%
df2.Type.groupby(df1.Type).count().sort_values(ascending = False)
# Out:
# Type
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
df2.Age[df2.Age ==  "� "].value_counts()
# Out:
# �     1
# Name: Age, dtype: int64

# %%
"""
def clean(x):
    pattern = r"\d+"
    res = re.findall(pattern,str(x)) 
    if res:
        return int(res[0])
    else:
        return x

df2["Age_cleaned"] = df2.Age.apply(clean)

"""
df2["Age"].unique()
# Out:
# array(['57', '11', '48', nan, '18', '52', '15', '12', '32', '10', '21',
#        '34', '30', '60', '33', '29', '54', '41', '37', '56', '19', '25',
#        '69', '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24',
#        '26', '49', '22', '7', '31', '17', '40', '13', '42', '3', '8',
#        '50', '16', '82', '73', '20s', '68', '51', '39', '58', 'Teen',
#        '47', '61', '65', '36', '66', '43', '60s', '9', '72', '59', '6',
#        '27', '64', '23', '71', '44', '62', '63', '70', '18 months', '53',
#        '30s', '50s', 'teen', '77', '74', '28 & 26', '5', '86', '18 or 20',
#        '12 or 13', '46 & 34', '28, 23 & 30', 'Teens', '36 & 26',
#        '8 or 10', '84', '� ', ' ', '30 or 36', '6�', '21 & ?', '75',
#        '33 or 37', 'mid-30s', '23 & 20', ' 30', '7      &    31', ' 28',
#        '20?', "60's", '32 & 30', '16 to 18', '87', '67', 'Elderly',
#        'mid-20s', 'Ca. 33', '74 ', '45 ', '21 or 26', '20 ', '>50',
# ...

# %%
df2["Age_cleaned"].unique()
# Out:
# array([57, 11, 48, nan, 18, 52, 15, 12, 32, 10, 21, 34, 30, 60, 33, 29,
#        54, 41, 37, 56, 19, 25, 69, 38, 55, 35, 46, 45, 14, 40, 28, 20, 24,
#        26, 49, 22, 7, 31, 17, 13, 42, 3, 8, 50, 16, 82, 73, 68, 51, 39,
#        58, 'Teen', 47, 61, 65, 36, 66, 43, 9, 72, 59, 6, 27, 64, 23, 71,
#        44, 62, 63, 70, 53, 'teen', 77, 74, 5, 86, 'Teens', 84, '� ', ' ',
#        75, 87, 67, 'Elderly', 'adult', 1, '(adult)', 'X', '"middle-age"',
#        2, 'MAKE LINE GREEN', 81, '"young"', 78, 'F', 'young', '  ',
#        'A.M.'], dtype=object)

# %%
df2.Age[df2.Age == 'young'].count()
# Out:
# 2

# %%
df2["Age_cleaned"] = df2.Age_cleaned.apply(lambda x: 20 if "young" in str(x) else x)
df2["Age_cleaned"] = df2.Age_cleaned.apply(lambda x: 15 if "teen" in str(x).lower() else x)
df2["Age_cleaned"] = df2.Age_cleaned.apply(lambda x: None if "�" in str(x).lower() else x)




df2["Age_cleaned"].unique()
# Out:
# array([57, 11, 48, nan, 18, 52, 15, 12, 32, 10, 21, 34, 30, 60, 33, 29,
#        54, 41, 37, 56, 19, 25, 69, 38, 55, 35, 46, 45, 14, 40, 28, 20, 24,
#        26, 49, 22, 7, 31, 17, 13, 42, 3, 8, 50, 16, 82, 73, 68, 51, 39,
#        58, 47, 61, 65, 36, 66, 43, 9, 72, 59, 6, 27, 64, 23, 71, 44, 62,
#        63, 70, 53, 77, 74, 5, 86, 84, None, ' ', 75, 87, 67, 'Elderly',
#        'adult', 1, '(adult)', 'X', '"middle-age"', 2, 'MAKE LINE GREEN',
#        81, 78, 'F', '  ', 'A.M.'], dtype=object)

# %%
b = "young younggg"
a = re.findall(r'\w+[oung]\w+',b)
a
# Out:
# ['young', 'younggg']

# %%
df2.Sex.value_counts()
# Out:
# M      5094
# F       637
# N         2
# M         2
# .         1
# lli       1
# Name: Sex, dtype: int64

# %%
df.Time.unique()
# Out:
# array(['18h00', '14h00  -15h00', '07h45', nan, 'Late afternoon', '17h00',
#        '14h00', 'Morning', '15h00', '08h15', '11h00', '10h30', '10h40',
#        '16h50', '07h00', '09h30', 'Afternoon', '21h50', '09h40', '08h00',
#        '17h35', '15h30', '07h30', '19h00, Dusk', 'Night', '16h00',
#        '15h01', '12h00', '13h45', '23h30', '09h00', '14h30', '18h30',
#        '12h30', '16h30', '18h45', '06h00', '10h00', '10h44', '13h19',
#        'Midday', '13h30', '10h45', '11h20', '11h45', '19h30', '08h30',
#        '15h45', 'Shortly before 12h00', '17h34', '17h10', '11h15',
#        '08h50', '17h45', '13h00', '10h20', '13h20', '02h00', '09h50',
#        '11h30', '17h30', '9h00', '10h43', 'After noon', '15h15', '15h40',
#        '19h05', '1300', '14h30 / 15h30', '22h00', '16h20', '14h34',
#        '15h25', '14h55', '17h46', 'Morning ', '15h49', '19h00',
#        'Midnight', '09h30 / 10h00', '10h15', '18h15', '04h00', '14h50',
# ...
